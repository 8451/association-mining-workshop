# %% [markdown]
# # 84.51º
# ## Association Rule Mining
#
# In retail data, knowing your customer is extremely important because
# it allows you to personalize the experience of each individual customer. At 84.51º,
# we take several different approaches to knowing our customer. One of the
# most basic and widely used topics is called the Association Rule Mining, which
# allows us to determine goods that are frequently purchased together.
#
# Let's consider some sample super market items:

# %%
items = {'milk', 'bread', 'cheese', 'eggs', 'soup', 'beer', 'cookies', 'crackers'}

# %% [markdown]
# Now, let's list some transactions, which consist of multiple items.

# %%
transactions = [
    {'milk', 'eggs'},
    {'beer', 'cheese', 'bread'},
    {'soup', 'cheese', 'bread', 'eggs', 'crackers'},
    {'cookies', 'soup', 'milk'},
    {'milk', 'eggs', 'cheese', 'bread'},
    {'milk', 'eggs', 'cookies'},
    {'cheese', 'beer', 'bread'},
    {'soup', 'crackers', 'bread'},
    {'bread', 'cheese', 'eggs'}
]

# %% [markdown]
# Now that we've got our transactions, we're going to go over some quick defintions to make our tasks easier:
#
# **Association Rule** - Rule of the form $X \implies Y$, where $X$ and $Y$ are item sets. Note the implication notation does not mean $X$ causes $Y$, but rather co-occurence.
#
# **Item Set** - A collection of one or more items.
#
# **K-Item Set** - An item set that contains `k` items.
#
# **Support Count** - Frequency of a particular item set
#
# **Support** - Fraction of transactions that contain a particular item set. $\frac{X}{\mid T \mid}$, where $X$ is the number of times the item set appears and $\mid T \mid$ is the number of total transactions.
#
# **Confidence** - Measures how often item in $Y$ appear in transactions that contain $X$.
#
# Here's some methods that implement some of the definitions:

# %%
def support_count(item_set, transactions):
    count = 0
    for transaction in transactions:
        # The <= sign means subset or equal set
        if item_set <= transaction:
            count += 1
    return count

def support(item_set, transactions):
    sc = support_count(item_set, transactions)
    return sc / len(transactions)

def confidence(item_set_x, item_set_y, transactions):
    x_u_y = item_set_x.union(item_set_y)
    return support_count(x_u_y, transactions) / support_count(item_set_x, transactions)

# %% [markdown]
# However, computing these for all possible item sets could take some time. Here's all the possible combinations for the 8 items available for baskets:

# %%
import itertools

for i in range(1, len(items)): # i will be what length of item sets we're looking for.
    for combo in itertools.combinations(items, i):
        print(combo)
# Out:
# ('soup',)
# ('cheese',)
# ('milk',)
# ('beer',)
# ('cookies',)
# ('eggs',)
# ('bread',)
# ('crackers',)
# ('soup', 'cheese')
# ('soup', 'milk')
# ('soup', 'beer')
# ('soup', 'cookies')
# ('soup', 'eggs')
# ('soup', 'bread')
# ('soup', 'crackers')
# ('cheese', 'milk')
# ('cheese', 'beer')
# ('cheese', 'cookies')
# ('cheese', 'eggs')
# ('cheese', 'bread')
# ('cheese', 'crackers')
# ('milk', 'beer')
# ('milk', 'cookies')
# ('milk', 'eggs')
# ('milk', 'bread')
# ('milk', 'crackers')
# ('beer', 'cookies')
# ('beer', 'eggs')
# ('beer', 'bread')
# ('beer', 'crackers')
# ('cookies', 'eggs')
# ('cookies', 'bread')
# ('cookies', 'crackers')
# ('eggs', 'bread')
# ('eggs', 'crackers')
# ('bread', 'crackers')
# ('soup', 'cheese', 'milk')
# ('soup', 'cheese', 'beer')
# ('soup', 'cheese', 'cookies')
# ('soup', 'cheese', 'eggs')
# ('soup', 'cheese', 'bread')
# ('soup', 'cheese', 'crackers')
# ('soup', 'milk', 'beer')
# ('soup', 'milk', 'cookies')
# ('soup', 'milk', 'eggs')
# ('soup', 'milk', 'bread')
# ('soup', 'milk', 'crackers')
# ('soup', 'beer', 'cookies')
# ('soup', 'beer', 'eggs')
# ('soup', 'beer', 'bread')
# ('soup', 'beer', 'crackers')
# ('soup', 'cookies', 'eggs')
# ('soup', 'cookies', 'bread')
# ('soup', 'cookies', 'crackers')
# ('soup', 'eggs', 'bread')
# ('soup', 'eggs', 'crackers')
# ('soup', 'bread', 'crackers')
# ('cheese', 'milk', 'beer')
# ('cheese', 'milk', 'cookies')
# ('cheese', 'milk', 'eggs')
# ('cheese', 'milk', 'bread')
# ('cheese', 'milk', 'crackers')
# ('cheese', 'beer', 'cookies')
# ('cheese', 'beer', 'eggs')
# ('cheese', 'beer', 'bread')
# ('cheese', 'beer', 'crackers')
# ('cheese', 'cookies', 'eggs')
# ('cheese', 'cookies', 'bread')
# ('cheese', 'cookies', 'crackers')
# ('cheese', 'eggs', 'bread')
# ('cheese', 'eggs', 'crackers')
# ('cheese', 'bread', 'crackers')
# ('milk', 'beer', 'cookies')
# ('milk', 'beer', 'eggs')
# ('milk', 'beer', 'bread')
# ('milk', 'beer', 'crackers')
# ('milk', 'cookies', 'eggs')
# ('milk', 'cookies', 'bread')
# ('milk', 'cookies', 'crackers')
# ('milk', 'eggs', 'bread')
# ('milk', 'eggs', 'crackers')
# ('milk', 'bread', 'crackers')
# ('beer', 'cookies', 'eggs')
# ('beer', 'cookies', 'bread')
# ('beer', 'cookies', 'crackers')
# ('beer', 'eggs', 'bread')
# ('beer', 'eggs', 'crackers')
# ('beer', 'bread', 'crackers')
# ('cookies', 'eggs', 'bread')
# ('cookies', 'eggs', 'crackers')
# ('cookies', 'bread', 'crackers')
# ('eggs', 'bread', 'crackers')
# ('soup', 'cheese', 'milk', 'beer')
# ('soup', 'cheese', 'milk', 'cookies')
# ('soup', 'cheese', 'milk', 'eggs')
# ('soup', 'cheese', 'milk', 'bread')
# ('soup', 'cheese', 'milk', 'crackers')
# ('soup', 'cheese', 'beer', 'cookies')
# ('soup', 'cheese', 'beer', 'eggs')
# ('soup', 'cheese', 'beer', 'bread')
# ('soup', 'cheese', 'beer', 'crackers')
# ('soup', 'cheese', 'cookies', 'eggs')
# ('soup', 'cheese', 'cookies', 'bread')
# ('soup', 'cheese', 'cookies', 'crackers')
# ('soup', 'cheese', 'eggs', 'bread')
# ('soup', 'cheese', 'eggs', 'crackers')
# ('soup', 'cheese', 'bread', 'crackers')
# ('soup', 'milk', 'beer', 'cookies')
# ('soup', 'milk', 'beer', 'eggs')
# ('soup', 'milk', 'beer', 'bread')
# ('soup', 'milk', 'beer', 'crackers')
# ('soup', 'milk', 'cookies', 'eggs')
# ('soup', 'milk', 'cookies', 'bread')
# ('soup', 'milk', 'cookies', 'crackers')
# ('soup', 'milk', 'eggs', 'bread')
# ('soup', 'milk', 'eggs', 'crackers')
# ('soup', 'milk', 'bread', 'crackers')
# ('soup', 'beer', 'cookies', 'eggs')
# ('soup', 'beer', 'cookies', 'bread')
# ('soup', 'beer', 'cookies', 'crackers')
# ('soup', 'beer', 'eggs', 'bread')
# ('soup', 'beer', 'eggs', 'crackers')
# ('soup', 'beer', 'bread', 'crackers')
# ('soup', 'cookies', 'eggs', 'bread')
# ('soup', 'cookies', 'eggs', 'crackers')
# ('soup', 'cookies', 'bread', 'crackers')
# ('soup', 'eggs', 'bread', 'crackers')
# ('cheese', 'milk', 'beer', 'cookies')
# ('cheese', 'milk', 'beer', 'eggs')
# ('cheese', 'milk', 'beer', 'bread')
# ('cheese', 'milk', 'beer', 'crackers')
# ('cheese', 'milk', 'cookies', 'eggs')
# ('cheese', 'milk', 'cookies', 'bread')
# ('cheese', 'milk', 'cookies', 'crackers')
# ('cheese', 'milk', 'eggs', 'bread')
# ('cheese', 'milk', 'eggs', 'crackers')
# ('cheese', 'milk', 'bread', 'crackers')
# ('cheese', 'beer', 'cookies', 'eggs')
# ('cheese', 'beer', 'cookies', 'bread')
# ('cheese', 'beer', 'cookies', 'crackers')
# ('cheese', 'beer', 'eggs', 'bread')
# ('cheese', 'beer', 'eggs', 'crackers')
# ('cheese', 'beer', 'bread', 'crackers')
# ('cheese', 'cookies', 'eggs', 'bread')
# ('cheese', 'cookies', 'eggs', 'crackers')
# ('cheese', 'cookies', 'bread', 'crackers')
# ('cheese', 'eggs', 'bread', 'crackers')
# ('milk', 'beer', 'cookies', 'eggs')
# ('milk', 'beer', 'cookies', 'bread')
# ('milk', 'beer', 'cookies', 'crackers')
# ('milk', 'beer', 'eggs', 'bread')
# ('milk', 'beer', 'eggs', 'crackers')
# ('milk', 'beer', 'bread', 'crackers')
# ('milk', 'cookies', 'eggs', 'bread')
# ('milk', 'cookies', 'eggs', 'crackers')
# ('milk', 'cookies', 'bread', 'crackers')
# ('milk', 'eggs', 'bread', 'crackers')
# ('beer', 'cookies', 'eggs', 'bread')
# ('beer', 'cookies', 'eggs', 'crackers')
# ('beer', 'cookies', 'bread', 'crackers')
# ('beer', 'eggs', 'bread', 'crackers')
# ('cookies', 'eggs', 'bread', 'crackers')
# ('soup', 'cheese', 'milk', 'beer', 'cookies')
# ('soup', 'cheese', 'milk', 'beer', 'eggs')
# ('soup', 'cheese', 'milk', 'beer', 'bread')
# ('soup', 'cheese', 'milk', 'beer', 'crackers')
# ('soup', 'cheese', 'milk', 'cookies', 'eggs')
# ('soup', 'cheese', 'milk', 'cookies', 'bread')
# ('soup', 'cheese', 'milk', 'cookies', 'crackers')
# ('soup', 'cheese', 'milk', 'eggs', 'bread')
# ('soup', 'cheese', 'milk', 'eggs', 'crackers')
# ('soup', 'cheese', 'milk', 'bread', 'crackers')
# ('soup', 'cheese', 'beer', 'cookies', 'eggs')
# ('soup', 'cheese', 'beer', 'cookies', 'bread')
# ('soup', 'cheese', 'beer', 'cookies', 'crackers')
# ('soup', 'cheese', 'beer', 'eggs', 'bread')
# ('soup', 'cheese', 'beer', 'eggs', 'crackers')
# ('soup', 'cheese', 'beer', 'bread', 'crackers')
# ('soup', 'cheese', 'cookies', 'eggs', 'bread')
# ('soup', 'cheese', 'cookies', 'eggs', 'crackers')
# ('soup', 'cheese', 'cookies', 'bread', 'crackers')
# ('soup', 'cheese', 'eggs', 'bread', 'crackers')
# ('soup', 'milk', 'beer', 'cookies', 'eggs')
# ('soup', 'milk', 'beer', 'cookies', 'bread')
# ('soup', 'milk', 'beer', 'cookies', 'crackers')
# ('soup', 'milk', 'beer', 'eggs', 'bread')
# ('soup', 'milk', 'beer', 'eggs', 'crackers')
# ('soup', 'milk', 'beer', 'bread', 'crackers')
# ('soup', 'milk', 'cookies', 'eggs', 'bread')
# ('soup', 'milk', 'cookies', 'eggs', 'crackers')
# ('soup', 'milk', 'cookies', 'bread', 'crackers')
# ('soup', 'milk', 'eggs', 'bread', 'crackers')
# ('soup', 'beer', 'cookies', 'eggs', 'bread')
# ('soup', 'beer', 'cookies', 'eggs', 'crackers')
# ('soup', 'beer', 'cookies', 'bread', 'crackers')
# ('soup', 'beer', 'eggs', 'bread', 'crackers')
# ('soup', 'cookies', 'eggs', 'bread', 'crackers')
# ('cheese', 'milk', 'beer', 'cookies', 'eggs')
# ('cheese', 'milk', 'beer', 'cookies', 'bread')
# ('cheese', 'milk', 'beer', 'cookies', 'crackers')
# ('cheese', 'milk', 'beer', 'eggs', 'bread')
# ('cheese', 'milk', 'beer', 'eggs', 'crackers')
# ('cheese', 'milk', 'beer', 'bread', 'crackers')
# ('cheese', 'milk', 'cookies', 'eggs', 'bread')
# ('cheese', 'milk', 'cookies', 'eggs', 'crackers')
# ('cheese', 'milk', 'cookies', 'bread', 'crackers')
# ('cheese', 'milk', 'eggs', 'bread', 'crackers')
# ('cheese', 'beer', 'cookies', 'eggs', 'bread')
# ('cheese', 'beer', 'cookies', 'eggs', 'crackers')
# ('cheese', 'beer', 'cookies', 'bread', 'crackers')
# ('cheese', 'beer', 'eggs', 'bread', 'crackers')
# ('cheese', 'cookies', 'eggs', 'bread', 'crackers')
# ('milk', 'beer', 'cookies', 'eggs', 'bread')
# ('milk', 'beer', 'cookies', 'eggs', 'crackers')
# ('milk', 'beer', 'cookies', 'bread', 'crackers')
# ('milk', 'beer', 'eggs', 'bread', 'crackers')
# ('milk', 'cookies', 'eggs', 'bread', 'crackers')
# ('beer', 'cookies', 'eggs', 'bread', 'crackers')
# ('soup', 'cheese', 'milk', 'beer', 'cookies', 'eggs')
# ('soup', 'cheese', 'milk', 'beer', 'cookies', 'bread')
# ('soup', 'cheese', 'milk', 'beer', 'cookies', 'crackers')
# ('soup', 'cheese', 'milk', 'beer', 'eggs', 'bread')
# ('soup', 'cheese', 'milk', 'beer', 'eggs', 'crackers')
# ('soup', 'cheese', 'milk', 'beer', 'bread', 'crackers')
# ('soup', 'cheese', 'milk', 'cookies', 'eggs', 'bread')
# ('soup', 'cheese', 'milk', 'cookies', 'eggs', 'crackers')
# ('soup', 'cheese', 'milk', 'cookies', 'bread', 'crackers')
# ('soup', 'cheese', 'milk', 'eggs', 'bread', 'crackers')
# ('soup', 'cheese', 'beer', 'cookies', 'eggs', 'bread')
# ('soup', 'cheese', 'beer', 'cookies', 'eggs', 'crackers')
# ('soup', 'cheese', 'beer', 'cookies', 'bread', 'crackers')
# ('soup', 'cheese', 'beer', 'eggs', 'bread', 'crackers')
# ('soup', 'cheese', 'cookies', 'eggs', 'bread', 'crackers')
# ('soup', 'milk', 'beer', 'cookies', 'eggs', 'bread')
# ('soup', 'milk', 'beer', 'cookies', 'eggs', 'crackers')
# ('soup', 'milk', 'beer', 'cookies', 'bread', 'crackers')
# ('soup', 'milk', 'beer', 'eggs', 'bread', 'crackers')
# ('soup', 'milk', 'cookies', 'eggs', 'bread', 'crackers')
# ('soup', 'beer', 'cookies', 'eggs', 'bread', 'crackers')
# ('cheese', 'milk', 'beer', 'cookies', 'eggs', 'bread')
# ('cheese', 'milk', 'beer', 'cookies', 'eggs', 'crackers')
# ('cheese', 'milk', 'beer', 'cookies', 'bread', 'crackers')
# ('cheese', 'milk', 'beer', 'eggs', 'bread', 'crackers')
# ('cheese', 'milk', 'cookies', 'eggs', 'bread', 'crackers')
# ('cheese', 'beer', 'cookies', 'eggs', 'bread', 'crackers')
# ('milk', 'beer', 'cookies', 'eggs', 'bread', 'crackers')
# ('soup', 'cheese', 'milk', 'beer', 'cookies', 'eggs', 'bread')
# ('soup', 'cheese', 'milk', 'beer', 'cookies', 'eggs', 'crackers')
# ('soup', 'cheese', 'milk', 'beer', 'cookies', 'bread', 'crackers')
# ('soup', 'cheese', 'milk', 'beer', 'eggs', 'bread', 'crackers')
# ('soup', 'cheese', 'milk', 'cookies', 'eggs', 'bread', 'crackers')
# ('soup', 'cheese', 'beer', 'cookies', 'eggs', 'bread', 'crackers')
# ('soup', 'milk', 'beer', 'cookies', 'eggs', 'bread', 'crackers')
# ('cheese', 'milk', 'beer', 'cookies', 'eggs', 'bread', 'crackers')

# %% [markdown]
# As you can imagine, computing frequent co-occurences of items can be prohibitively and computationally expensive, especially if you're working with a large number of products. At Kroger, we have at least a few thousand unique items which would make this kind of computation take an inordinate amount of time. This is because the number of combinations grows at a rate of $2^n$, where $n$ is the number of available items. Even if we had just 1,000 items, the total number of item sets would overflow an unsigned 64 bit integer. (Which has a maximum value of 18,446,744,073,709,551,615, or 18 quintillion for those keeping track at home)
#
# However, we can make the task significantly easier by finding rules with **support and confidence values greater than a threshold**. For example, we care about items that are frequently purchased together, and don't care about pairs that aren't purchased frequently together. We're going to write a method that can compute the support and confidence of a given item set that you can use later.
#
# # The Brute Force Way

# %%
import itertools

def combinations(items):
    for i in range(1, len(items)):
        for combo in itertools.combinations(items, i):
           yield combo
        
answers = []
checks = 0
for combo in combinations(items):
    checks += 1
    if support(set(combo), transactions) >= .5:
        answers.append(combo)

print('Checked ' + str(checks) + ' item sets.')
print('The ones with 50% or more?: ', answers)
# Out:
# Checked 254 item sets.
# The ones with 50% or more?:  [('cheese',), ('eggs',), ('bread',), ('cheese', 'bread')]

# %% [markdown]
# # Do you know of any way that we can make this computation go a bit quicker, instead of computing it for all possible item sets?
#
#
# ## Any ideas?
#
# Hint: Can a superset of a particular item set have a higher support than a particular item set?
#
#
# This is called an **apriori** algorithim and is covered in many Data Science courses. It works by ignoring supersets whose subsets have a support lower than the threshold. **Why?**
#
# We're going to use some common data science libraries in Python to do this. We're going to use a combination of Panda and mlxtend to do this in a much more efficient manner.

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

encoder = TransactionEncoder() # note: we can also use a sparse encoder to save space. Useful for large datasets
dataset = encoder.fit(transactions).transform(transactions)
frame = pd.DataFrame(dataset, columns=encoder.columns_)
print("The representation that mlxtend uses:")
print(frame)
# Out:
# The representation that mlxtend uses:
#     beer  bread  cheese  cookies  crackers   eggs   milk   soup
# 0  False  False   False    False     False   True   True  False
# 1   True   True    True    False     False  False  False  False
# 2  False   True    True    False      True   True  False   True
# 3  False  False   False     True     False  False   True   True
# 4  False   True    True    False     False   True   True  False
# 5  False  False   False     True     False   True   True  False
# 6   True   True    True    False     False  False  False  False
# 7  False   True   False    False      True  False  False   True
# 8  False   True    True    False     False   True  False  False

# %%
from mlxtend.frequent_patterns import apriori

print(apriori(frame, min_support=0.5, use_colnames=True))
# Out:
#     support         itemsets
# 0  0.666667          (bread)
# 1  0.555556         (cheese)
# 2  0.555556           (eggs)
# 3  0.555556  (cheese, bread)

# %% [markdown]
# # Conclusion
#
# This is just a brief example of one of the tools in our toolbox at 84.51º.
#
# If you're interested in working at 84.51º, please contact your recruiters for more detailed instructions or apply directly [online](http://8451.com).
